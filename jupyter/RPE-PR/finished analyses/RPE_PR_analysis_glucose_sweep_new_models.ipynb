# %%
# set cwd and solver
import os
import cobra
cobra.Configuration().solver = "gurobi"
os.chdir('C:/Users/prins/GitHub/Human1_RPE-PR')

# %%
# load all models in \cs_mods\July2023 folder by cycling through names
from cobra.io import read_sbml_model    
import glob 
import os   
from pathlib import Path
import pandas as pd

# do not change directory but still go to the folder with the models
folder = Path().cwd() / "cs_mods" / "July2023"
model_list = []
for file in folder.glob("*.xml"):  
    model = read_sbml_model(file)
    model.id = file.stem # remove .xml 
    model.name = file.stem # remove .xml
    model_list.append(model)
# Out:
# No objective coefficients in model. Unclear what should be optimized
# No objective coefficients in model. Unclear what should be optimized
# No objective coefficients in model. Unclear what should be optimized
# No objective coefficients in model. Unclear what should be optimized

# %%
# load old combined RPE_PR models
mod_RPE_PR = read_sbml_model(Path().cwd() / "models" / "mod_RPE_PR.xml")
mod_RPE_PR.id = 'RPE_PR_old'
mod_RPE_PR.name = 'RPE_PR_old'
mod_Human1_Human1 = read_sbml_model(Path().cwd() / "models" /  "mod_Human1_Human1.xml")
mod_Human1_Human1.id = 'RPE_PR_control_old'
mod_Human1_Human1.name = 'RPE_PR_control_old'
mod = read_sbml_model(Path().cwd() / 'models/Human-GEM.xml')
mod.id = 'Human1_old'
mod.name = 'Human1_old'

# add old models to model_list
model_list = model_list + [mod,mod_RPE_PR]

# check out model_list
model_list
# Out:
# [<Model Human-GEM_28062023 at 0x1b3287bd7b0>,
#  <Model mod_RPE_PRcone_Liang at 0x1b32dbdb1f0>,
#  <Model mod_RPE_PRcone_Liang_singlePR at 0x1b3352ebe80>,
#  <Model mod_RPE_PRcone_Liang_singleRPE at 0x1b33884afb0>,
#  <Model mod_RPE_PRcone_Lukowski at 0x1b33d28c070>,
#  <Model mod_RPE_PRcone_Lukowski_singlePR at 0x1b344bf7700>,
#  <Model mod_RPE_PRcone_Lukowski_singleRPE at 0x1b348a87850>,
#  <Model mod_RPE_PRcontrol at 0x1b34cbd5030>,
#  <Model mod_RPE_PRrod_Liang at 0x1b3626d6920>,
#  <Model mod_RPE_PRrod_Liang_singlePR at 0x1b3761da650>,
#  <Model mod_RPE_PRrod_Liang_singleRPE at 0x1b3784ae6b0>,
#  <Model mod_RPE_PRrod_Lukowski at 0x1b37c5c9f30>,
#  <Model mod_RPE_PRrod_Lukowski_singlePR at 0x1b385af6560>,
#  <Model mod_RPE_PRrod_Lukowski_singleRPE at 0x1b387f27cd0>,
#  <Model Human1_old at 0x1b3a8c3f730>,
#  <Model RPE_PR_old at 0x1b32833df60>]

# %%
# modify models
# load blood exchange bounds
df = pd.read_excel(Path().cwd() / 'rxn_bounds/blood_selection.xlsx') # with col names 'id' 'lb' 'ub'

# for all models in the list set objective function (ATP hydrolysis, in PR for combined models)
for m in model_list:
    if 'MAR03964_PR' in [r.id for r in m.reactions]:
        m.objective = 'MAR03964_PR'
    elif 'MAR03964_RPE' in [r.id for r in m.reactions]:
        m.objective = 'MAR03964_RPE'
    elif 'MAR03964' in [r.id for r in m.reactions]:
        m.objective = 'MAR03964'
    else:
        print('no ATP hydrolysis reaction (MAR03964) in model: ' + m.id)

# list combined and single models
combined_models = [m for m in model_list if 'single' not in m.id and 'Human' not in m.id]
single_models = [m for m in model_list if 'single' in m.id]
Human1_models = [m for m in model_list if 'Human' in m.id]

# close PR exchange in combined models and open RPE exchange (efflux)
for m in combined_models:
    for r in [r for r in m.reactions if len(r.products) == 0 ]:           # close all exchange reactions
        r.bounds=(0,0)
    for r in [r for r in m.reactions if len(r.products) == 0 if '_RPE' in r.id]:           # open efflux for RPE exchange reactions
        r.bounds=(0,1000) 

# only allow efflux exchange in single models
for m in single_models:
    for r in [r for r in m.reactions if len(r.products) == 0 ]:           # close all exchange reactions
        r.bounds=(0,1000)

# for Human1 models, open efflux
for m in [m for m in model_list if 'Human' in m.id]:
    for r in [r for r in m.reactions if len(r.products) == 0]:           # open efflux for RPE exchange reactions
        r.bounds=(0,1000)

# %%
def set_exchange_bounds(model, ex_dict): 
    """
    set bounds for exchange reactions in model based on dict

    Parameters
    ----------
    model : cobra.Model
        model to set bounds for
    ex_dict : dict
        dictionary with exchange reaction ids as keys and bounds as values

    Returns
    -------
    model : cobra.Model
        model with updated bounds

    """

    for ex in ex_dict.keys():
        if ex + '_RPE' in [r.id for r in model.reactions]:
            model.reactions.get_by_id(ex + '_RPE').bounds = ex_dict[ex] # set bounds for RPE exchange
        elif ex + '_PR' in [r.id for r in model.reactions]:
            model.reactions.get_by_id(ex + '_PR').bounds = ex_dict[ex] # if no RPE exchange, set bounds for PR exchange
        elif ex + '_eRPE_PR' in [r.id for r in model.reactions]:
            model.reactions.get_by_id(ex + '_eRPE_PR').bounds = ex_dict[ex] # if no RPE or PR exchange, set bounds for eRPE_PR exchange
        elif ex in [r.id for r in model.reactions]:
            model.reactions.get_by_id(ex).bounds = ex_dict[ex] # if no RPE, PR, or eRPE_PR exchange, set bounds for exchange (generic)
        else:  
            print('no exchange reaction for ' + ex + ' in model: ' + model.id) # if no exchange reaction, print message
    return model 



ex_bounds = {'MAR09048':(-3.51,1000),'MAR09034':(-4.18,1000),'MAR09135':(7.25,1000)}


results_dict = {}
for m in model_list:
    set_exchange_bounds(m, ex_bounds)
    m.optimize()
    results_dict[m.id] = m.objective.value
df1 = pd.DataFrame(results_dict, index = ['max ATP hydrolysis (pmol/s/mm^2)']).T
df1
# Out:
#                                    max ATP hydrolysis (pmol/s/mm^2)
# Human-GEM_28062023                                          24.7325
# mod_RPE_PRcone_Liang                                        23.9000
# mod_RPE_PRcone_Liang_singlePR                               11.1350
# mod_RPE_PRcone_Liang_singleRPE                              23.9000
# mod_RPE_PRcone_Lukowski                                     24.7325
# mod_RPE_PRcone_Lukowski_singlePR                            22.2350
# mod_RPE_PRcone_Lukowski_singleRPE                           23.9000
# mod_RPE_PRcontrol                                           24.7325
# mod_RPE_PRrod_Liang                                         23.9000
# mod_RPE_PRrod_Liang_singlePR                                13.9100
# mod_RPE_PRrod_Liang_singleRPE                               23.9000
# mod_RPE_PRrod_Lukowski                                      24.7325
# mod_RPE_PRrod_Lukowski_singlePR                             23.9000
# mod_RPE_PRrod_Lukowski_singleRPE                            23.9000
# Human1_old                                                  24.7325
# RPE_PR_old                                                  24.7325

# %%
ex_bounds = {'MAR09048':(-3.51,1000),'MAR09034':(-4.18,1000),'MAR09135':(7.25,1000)}

def fba_(model_list, ex_bounds, sweep_list, sweep_reaction):

    df3 = pd.DataFrame()
    for i in sweep_list:
        results_dict = {}
        for m in model_list:
            set_exchange_bounds(m, ex_bounds)
            set_exchange_bounds(m, {sweep_reaction:(-i,1000)})
            m.optimize()
            results_dict[m.id] = m.objective.value
        df2 = pd.DataFrame(results_dict, index = [str(i) + \
            ' pmol/s/mm^2 influx ' + str(sweep_reaction) +\
            ' --- max ATP hydrolysis (pmol/s/mm^2)']).T
        # put all results in one df using concat    
        df3 = pd.concat([df3,df2],axis=1)

    return df3

sweep_list = [1,2,3,4,4.18,5,6,7,8,9, 10, 100, 1000]
sweep_reaction = 'MAR09034'
ex_bounds = {'MAR09048':(-3.51,1000),'MAR09034':(-4.18,1000),'MAR09135':(7.25,1000)}
df3 = fba_(model_list, ex_bounds, sweep_list, sweep_reaction)
df3
# Out:
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
#                                   1 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                              None
# mod_RPE_PRcone_Liang                                                            None
# mod_RPE_PRcone_Liang_singlePR                                                   None
# mod_RPE_PRcone_Liang_singleRPE                                                  None
# mod_RPE_PRcone_Lukowski                                                         None
# mod_RPE_PRcone_Lukowski_singlePR                                                None
# mod_RPE_PRcone_Lukowski_singleRPE                                               None
# mod_RPE_PRcontrol                                                               None
# mod_RPE_PRrod_Liang                                                             None
# mod_RPE_PRrod_Liang_singlePR                                                    None
# mod_RPE_PRrod_Liang_singleRPE                                                   None
# mod_RPE_PRrod_Lukowski                                                          None
# mod_RPE_PRrod_Lukowski_singlePR                                                 None
# mod_RPE_PRrod_Lukowski_singleRPE                                                None
# Human1_old                                                                      None
# RPE_PR_old                                                                      None
#
#                                   2 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                              None
# mod_RPE_PRcone_Liang                                                            None
# mod_RPE_PRcone_Liang_singlePR                                                   None
# mod_RPE_PRcone_Liang_singleRPE                                                  None
# mod_RPE_PRcone_Lukowski                                                         None
# mod_RPE_PRcone_Lukowski_singlePR                                                None
# mod_RPE_PRcone_Lukowski_singleRPE                                               None
# mod_RPE_PRcontrol                                                               None
# mod_RPE_PRrod_Liang                                                             None
# mod_RPE_PRrod_Liang_singlePR                                                    None
# mod_RPE_PRrod_Liang_singleRPE                                                   None
# mod_RPE_PRrod_Lukowski                                                          None
# mod_RPE_PRrod_Lukowski_singlePR                                                 None
# mod_RPE_PRrod_Lukowski_singleRPE                                                None
# Human1_old                                                                      None
# RPE_PR_old                                                                      None
#
#                                   3 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                              None
# mod_RPE_PRcone_Liang                                                            None
# mod_RPE_PRcone_Liang_singlePR                                                   None
# mod_RPE_PRcone_Liang_singleRPE                                                  None
# mod_RPE_PRcone_Lukowski                                                         None
# mod_RPE_PRcone_Lukowski_singlePR                                                None
# mod_RPE_PRcone_Lukowski_singleRPE                                               None
# mod_RPE_PRcontrol                                                               None
# mod_RPE_PRrod_Liang                                                             None
# mod_RPE_PRrod_Liang_singlePR                                                    None
# mod_RPE_PRrod_Liang_singleRPE                                                   None
# mod_RPE_PRrod_Lukowski                                                          None
# mod_RPE_PRrod_Lukowski_singlePR                                                 None
# mod_RPE_PRrod_Lukowski_singleRPE                                                None
# Human1_old                                                                      None
# RPE_PR_old                                                                      None
#
#                                    4 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                           19.0625
# mod_RPE_PRcone_Liang                                                         18.5000
# mod_RPE_PRcone_Liang_singlePR                                                 9.8750
# mod_RPE_PRcone_Liang_singleRPE                                               18.5000
# mod_RPE_PRcone_Lukowski                                                      19.0625
# mod_RPE_PRcone_Lukowski_singlePR                                             17.3750
# mod_RPE_PRcone_Lukowski_singleRPE                                            18.5000
# mod_RPE_PRcontrol                                                            19.0625
# mod_RPE_PRrod_Liang                                                          18.5000
# mod_RPE_PRrod_Liang_singlePR                                                 11.7500
# mod_RPE_PRrod_Liang_singleRPE                                                18.5000
# mod_RPE_PRrod_Lukowski                                                       19.0625
# mod_RPE_PRrod_Lukowski_singlePR                                              18.5000
# mod_RPE_PRrod_Lukowski_singleRPE                                             18.5000
# Human1_old                                                                   19.0625
# RPE_PR_old                                                                   19.0625
#
#                                    4.18 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                           24.7325
# mod_RPE_PRcone_Liang                                                         23.9000
# mod_RPE_PRcone_Liang_singlePR                                                11.1350
# mod_RPE_PRcone_Liang_singleRPE                                               23.9000
# mod_RPE_PRcone_Lukowski                                                      24.7325
# mod_RPE_PRcone_Lukowski_singlePR                                             22.2350
# mod_RPE_PRcone_Lukowski_singleRPE                                            23.9000
# mod_RPE_PRcontrol                                                            24.7325
# mod_RPE_PRrod_Liang                                                          23.9000
# mod_RPE_PRrod_Liang_singlePR                                                 13.9100
# mod_RPE_PRrod_Liang_singleRPE                                                23.9000
# mod_RPE_PRrod_Lukowski                                                       24.7325
# mod_RPE_PRrod_Lukowski_singlePR                                              23.9000
# mod_RPE_PRrod_Lukowski_singleRPE                                             23.9000
# Human1_old                                                                   24.7325
# RPE_PR_old                                                                   24.7325
#
#                                    5 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                         27.455000
# mod_RPE_PRcone_Liang                                                       27.170000
# mod_RPE_PRcone_Liang_singlePR                                              16.875000
# mod_RPE_PRcone_Liang_singleRPE                                             27.170000
# mod_RPE_PRcone_Lukowski                                                    27.455000
# mod_RPE_PRcone_Lukowski_singlePR                                           26.600000
# mod_RPE_PRcone_Lukowski_singleRPE                                          27.170000
# mod_RPE_PRcontrol                                                          27.455000
# mod_RPE_PRrod_Liang                                                        27.170000
# mod_RPE_PRrod_Liang_singlePR                                               23.750000
# mod_RPE_PRrod_Liang_singleRPE                                              27.170000
# mod_RPE_PRrod_Lukowski                                                     27.455000
# mod_RPE_PRrod_Lukowski_singlePR                                            26.696000
# mod_RPE_PRrod_Lukowski_singleRPE                                           27.170000
# Human1_old                                                                 27.455000
# RPE_PR_old                                                                 27.715577
#
#                                    6 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                         29.550000
# mod_RPE_PRcone_Liang                                                       29.550000
# mod_RPE_PRcone_Liang_singlePR                                              23.875000
# mod_RPE_PRcone_Liang_singleRPE                                             29.550000
# mod_RPE_PRcone_Lukowski                                                    29.550000
# mod_RPE_PRcone_Lukowski_singlePR                                           29.550000
# mod_RPE_PRcone_Lukowski_singleRPE                                          29.550000
# mod_RPE_PRcontrol                                                          29.550000
# mod_RPE_PRrod_Liang                                                        29.550000
# mod_RPE_PRrod_Liang_singlePR                                               29.550000
# mod_RPE_PRrod_Liang_singleRPE                                              29.550000
# mod_RPE_PRrod_Lukowski                                                     29.550000
# mod_RPE_PRrod_Lukowski_singlePR                                            29.096000
# mod_RPE_PRrod_Lukowski_singleRPE                                           29.550000
# Human1_old                                                                 29.550000
# RPE_PR_old                                                                 29.817259
#
#                                    7 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                         31.550000
# mod_RPE_PRcone_Liang                                                       31.550000
# mod_RPE_PRcone_Liang_singlePR                                              30.875000
# mod_RPE_PRcone_Liang_singleRPE                                             31.550000
# mod_RPE_PRcone_Lukowski                                                    31.550000
# mod_RPE_PRcone_Lukowski_singlePR                                           31.550000
# mod_RPE_PRcone_Lukowski_singleRPE                                          31.550000
# mod_RPE_PRcontrol                                                          31.550000
# mod_RPE_PRrod_Liang                                                        31.550000
# mod_RPE_PRrod_Liang_singlePR                                               31.550000
# mod_RPE_PRrod_Liang_singleRPE                                              31.550000
# mod_RPE_PRrod_Lukowski                                                     31.550000
# mod_RPE_PRrod_Lukowski_singlePR                                            31.496000
# mod_RPE_PRrod_Lukowski_singleRPE                                           31.550000
# Human1_old                                                                 31.550000
# RPE_PR_old                                                                 31.817259
#
#                                    8 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                         33.550000
# mod_RPE_PRcone_Liang                                                       33.550000
# mod_RPE_PRcone_Liang_singlePR                                              33.550000
# mod_RPE_PRcone_Liang_singleRPE                                             33.550000
# mod_RPE_PRcone_Lukowski                                                    33.550000
# mod_RPE_PRcone_Lukowski_singlePR                                           33.550000
# mod_RPE_PRcone_Lukowski_singleRPE                                          33.550000
# mod_RPE_PRcontrol                                                          33.550000
# mod_RPE_PRrod_Liang                                                        33.550000
# mod_RPE_PRrod_Liang_singlePR                                               33.550000
# mod_RPE_PRrod_Liang_singleRPE                                              33.550000
# mod_RPE_PRrod_Lukowski                                                     33.550000
# mod_RPE_PRrod_Lukowski_singlePR                                            33.550000
# mod_RPE_PRrod_Lukowski_singleRPE                                           33.550000
# Human1_old                                                                 33.550000
# RPE_PR_old                                                                 33.817259
#
#                                    9 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                         35.550000
# mod_RPE_PRcone_Liang                                                       35.550000
# mod_RPE_PRcone_Liang_singlePR                                              35.550000
# mod_RPE_PRcone_Liang_singleRPE                                             35.550000
# mod_RPE_PRcone_Lukowski                                                    35.550000
# mod_RPE_PRcone_Lukowski_singlePR                                           35.550000
# mod_RPE_PRcone_Lukowski_singleRPE                                          35.550000
# mod_RPE_PRcontrol                                                          35.550000
# mod_RPE_PRrod_Liang                                                        35.550000
# mod_RPE_PRrod_Liang_singlePR                                               35.550000
# mod_RPE_PRrod_Liang_singleRPE                                              35.550000
# mod_RPE_PRrod_Lukowski                                                     35.550000
# mod_RPE_PRrod_Lukowski_singlePR                                            35.550000
# mod_RPE_PRrod_Lukowski_singleRPE                                           35.550000
# Human1_old                                                                 35.550000
# RPE_PR_old                                                                 35.817259
#
#                                    10 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                         37.550000
# mod_RPE_PRcone_Liang                                                       37.550000
# mod_RPE_PRcone_Liang_singlePR                                              37.550000
# mod_RPE_PRcone_Liang_singleRPE                                             37.550000
# mod_RPE_PRcone_Lukowski                                                    37.550000
# mod_RPE_PRcone_Lukowski_singlePR                                           37.550000
# mod_RPE_PRcone_Lukowski_singleRPE                                          37.550000
# mod_RPE_PRcontrol                                                          37.550000
# mod_RPE_PRrod_Liang                                                        37.550000
# mod_RPE_PRrod_Liang_singlePR                                               37.550000
# mod_RPE_PRrod_Liang_singleRPE                                              37.550000
# mod_RPE_PRrod_Lukowski                                                     37.550000
# mod_RPE_PRrod_Lukowski_singlePR                                            37.550000
# mod_RPE_PRrod_Lukowski_singleRPE                                           37.550000
# Human1_old                                                                 37.550000
# RPE_PR_old                                                                 37.817259
#
#                                    100 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                        217.550000
# mod_RPE_PRcone_Liang                                                      217.550000
# mod_RPE_PRcone_Liang_singlePR                                             217.550000
# mod_RPE_PRcone_Liang_singleRPE                                            217.550000
# mod_RPE_PRcone_Lukowski                                                   217.550000
# mod_RPE_PRcone_Lukowski_singlePR                                          217.550000
# mod_RPE_PRcone_Lukowski_singleRPE                                         217.550000
# mod_RPE_PRcontrol                                                         217.550000
# mod_RPE_PRrod_Liang                                                       217.550000
# mod_RPE_PRrod_Liang_singlePR                                              217.550000
# mod_RPE_PRrod_Liang_singleRPE                                             217.550000
# mod_RPE_PRrod_Lukowski                                                    217.550000
# mod_RPE_PRrod_Lukowski_singlePR                                           217.550000
# mod_RPE_PRrod_Lukowski_singleRPE                                          217.550000
# Human1_old                                                                217.550000
# RPE_PR_old                                                                217.817259
#
#                                    1000 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)
# Human-GEM_28062023                                                            1000.0
# mod_RPE_PRcone_Liang                                                          1000.0
# mod_RPE_PRcone_Liang_singlePR                                                 1000.0
# mod_RPE_PRcone_Liang_singleRPE                                                1000.0
# mod_RPE_PRcone_Lukowski                                                       1000.0
# mod_RPE_PRcone_Lukowski_singlePR                                              1000.0
# mod_RPE_PRcone_Lukowski_singleRPE                                             1000.0
# mod_RPE_PRcontrol                                                             1000.0
# mod_RPE_PRrod_Liang                                                           1000.0
# mod_RPE_PRrod_Liang_singlePR                                                  1000.0
# mod_RPE_PRrod_Liang_singleRPE                                                 1000.0
# mod_RPE_PRrod_Lukowski                                                        1000.0
# mod_RPE_PRrod_Lukowski_singlePR                                               1000.0
# mod_RPE_PRrod_Lukowski_singleRPE                                              1000.0
# Human1_old                                                                    1000.0
# RPE_PR_old                                                                    1000.0

# %%
sweep_list = [1,2,3,4,4.18,5,6,7,8,9, 10, 100, 1000]
sweep_reaction = 'MAR09034'
ex_bounds = {'MAR09048':(-3.51,1000),'MAR09034':(-4.18,1000),'MAR09135':(0,1000)}
df4 = fba_(model_list, ex_bounds, sweep_list, sweep_reaction)
df4
# Out:
#                                    1 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                         19.361250
# mod_RPE_PRcone_Liang                                                       18.795000
# mod_RPE_PRcone_Liang_singlePR                                               7.000000
# mod_RPE_PRcone_Liang_singleRPE                                             18.795000
# mod_RPE_PRcone_Lukowski                                                    19.361250
# mod_RPE_PRcone_Lukowski_singlePR                                           17.662500
# mod_RPE_PRcone_Lukowski_singleRPE                                          18.795000
# mod_RPE_PRcontrol                                                          19.361250
# mod_RPE_PRrod_Liang                                                        18.795000
# mod_RPE_PRrod_Liang_singlePR                                               12.000000
# mod_RPE_PRrod_Liang_singleRPE                                              18.795000
# mod_RPE_PRrod_Lukowski                                                     19.361250
# mod_RPE_PRrod_Lukowski_singlePR                                            18.542000
# mod_RPE_PRrod_Lukowski_singleRPE                                           18.795000
# Human1_old                                                                 19.361250
# RPE_PR_old                                                                 19.621827
#
#                                    2 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                         21.550000
# mod_RPE_PRcone_Liang                                                       21.550000
# mod_RPE_PRcone_Liang_singlePR                                              14.000000
# mod_RPE_PRcone_Liang_singleRPE                                             21.550000
# mod_RPE_PRcone_Lukowski                                                    21.550000
# mod_RPE_PRcone_Lukowski_singlePR                                           21.550000
# mod_RPE_PRcone_Lukowski_singleRPE                                          21.550000
# mod_RPE_PRcontrol                                                          21.550000
# mod_RPE_PRrod_Liang                                                        21.550000
# mod_RPE_PRrod_Liang_singlePR                                               21.550000
# mod_RPE_PRrod_Liang_singleRPE                                              21.550000
# mod_RPE_PRrod_Lukowski                                                     21.550000
# mod_RPE_PRrod_Lukowski_singlePR                                            20.946000
# mod_RPE_PRrod_Lukowski_singleRPE                                           21.550000
# Human1_old                                                                 21.550000
# RPE_PR_old                                                                 21.817259
#
#                                    3 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                         23.550000
# mod_RPE_PRcone_Liang                                                       23.550000
# mod_RPE_PRcone_Liang_singlePR                                              21.000000
# mod_RPE_PRcone_Liang_singleRPE                                             23.550000
# mod_RPE_PRcone_Lukowski                                                    23.550000
# mod_RPE_PRcone_Lukowski_singlePR                                           23.550000
# mod_RPE_PRcone_Lukowski_singleRPE                                          23.550000
# mod_RPE_PRcontrol                                                          23.550000
# mod_RPE_PRrod_Liang                                                        23.550000
# mod_RPE_PRrod_Liang_singlePR                                               23.550000
# mod_RPE_PRrod_Liang_singleRPE                                              23.550000
# mod_RPE_PRrod_Lukowski                                                     23.550000
# mod_RPE_PRrod_Lukowski_singlePR                                            23.346000
# mod_RPE_PRrod_Lukowski_singleRPE                                           23.550000
# Human1_old                                                                 23.550000
# RPE_PR_old                                                                 23.817259
#
#                                    4 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                         25.550000
# mod_RPE_PRcone_Liang                                                       25.550000
# mod_RPE_PRcone_Liang_singlePR                                              25.550000
# mod_RPE_PRcone_Liang_singleRPE                                             25.550000
# mod_RPE_PRcone_Lukowski                                                    25.550000
# mod_RPE_PRcone_Lukowski_singlePR                                           25.550000
# mod_RPE_PRcone_Lukowski_singleRPE                                          25.550000
# mod_RPE_PRcontrol                                                          25.550000
# mod_RPE_PRrod_Liang                                                        25.550000
# mod_RPE_PRrod_Liang_singlePR                                               25.550000
# mod_RPE_PRrod_Liang_singleRPE                                              25.550000
# mod_RPE_PRrod_Lukowski                                                     25.550000
# mod_RPE_PRrod_Lukowski_singlePR                                            25.550000
# mod_RPE_PRrod_Lukowski_singleRPE                                           25.550000
# Human1_old                                                                 25.550000
# RPE_PR_old                                                                 25.817259
#
#                                    4.18 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                         25.910000
# mod_RPE_PRcone_Liang                                                       25.910000
# mod_RPE_PRcone_Liang_singlePR                                              25.910000
# mod_RPE_PRcone_Liang_singleRPE                                             25.910000
# mod_RPE_PRcone_Lukowski                                                    25.910000
# mod_RPE_PRcone_Lukowski_singlePR                                           25.910000
# mod_RPE_PRcone_Lukowski_singleRPE                                          25.910000
# mod_RPE_PRcontrol                                                          25.910000
# mod_RPE_PRrod_Liang                                                        25.910000
# mod_RPE_PRrod_Liang_singlePR                                               25.910000
# mod_RPE_PRrod_Liang_singleRPE                                              25.910000
# mod_RPE_PRrod_Lukowski                                                     25.910000
# mod_RPE_PRrod_Lukowski_singlePR                                            25.910000
# mod_RPE_PRrod_Lukowski_singleRPE                                           25.910000
# Human1_old                                                                 25.910000
# RPE_PR_old                                                                 26.177259
#
#                                    5 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                         27.550000
# mod_RPE_PRcone_Liang                                                       27.550000
# mod_RPE_PRcone_Liang_singlePR                                              27.550000
# mod_RPE_PRcone_Liang_singleRPE                                             27.550000
# mod_RPE_PRcone_Lukowski                                                    27.550000
# mod_RPE_PRcone_Lukowski_singlePR                                           27.550000
# mod_RPE_PRcone_Lukowski_singleRPE                                          27.550000
# mod_RPE_PRcontrol                                                          27.550000
# mod_RPE_PRrod_Liang                                                        27.550000
# mod_RPE_PRrod_Liang_singlePR                                               27.550000
# mod_RPE_PRrod_Liang_singleRPE                                              27.550000
# mod_RPE_PRrod_Lukowski                                                     27.550000
# mod_RPE_PRrod_Lukowski_singlePR                                            27.550000
# mod_RPE_PRrod_Lukowski_singleRPE                                           27.550000
# Human1_old                                                                 27.550000
# RPE_PR_old                                                                 27.817259
#
#                                    6 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                         29.550000
# mod_RPE_PRcone_Liang                                                       29.550000
# mod_RPE_PRcone_Liang_singlePR                                              29.550000
# mod_RPE_PRcone_Liang_singleRPE                                             29.550000
# mod_RPE_PRcone_Lukowski                                                    29.550000
# mod_RPE_PRcone_Lukowski_singlePR                                           29.550000
# mod_RPE_PRcone_Lukowski_singleRPE                                          29.550000
# mod_RPE_PRcontrol                                                          29.550000
# mod_RPE_PRrod_Liang                                                        29.550000
# mod_RPE_PRrod_Liang_singlePR                                               29.550000
# mod_RPE_PRrod_Liang_singleRPE                                              29.550000
# mod_RPE_PRrod_Lukowski                                                     29.550000
# mod_RPE_PRrod_Lukowski_singlePR                                            29.550000
# mod_RPE_PRrod_Lukowski_singleRPE                                           29.550000
# Human1_old                                                                 29.550000
# RPE_PR_old                                                                 29.817259
#
#                                    7 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                         31.550000
# mod_RPE_PRcone_Liang                                                       31.550000
# mod_RPE_PRcone_Liang_singlePR                                              31.550000
# mod_RPE_PRcone_Liang_singleRPE                                             31.550000
# mod_RPE_PRcone_Lukowski                                                    31.550000
# mod_RPE_PRcone_Lukowski_singlePR                                           31.550000
# mod_RPE_PRcone_Lukowski_singleRPE                                          31.550000
# mod_RPE_PRcontrol                                                          31.550000
# mod_RPE_PRrod_Liang                                                        31.550000
# mod_RPE_PRrod_Liang_singlePR                                               31.550000
# mod_RPE_PRrod_Liang_singleRPE                                              31.550000
# mod_RPE_PRrod_Lukowski                                                     31.550000
# mod_RPE_PRrod_Lukowski_singlePR                                            31.550000
# mod_RPE_PRrod_Lukowski_singleRPE                                           31.550000
# Human1_old                                                                 31.550000
# RPE_PR_old                                                                 31.817259
#
#                                    8 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                         33.550000
# mod_RPE_PRcone_Liang                                                       33.550000
# mod_RPE_PRcone_Liang_singlePR                                              33.550000
# mod_RPE_PRcone_Liang_singleRPE                                             33.550000
# mod_RPE_PRcone_Lukowski                                                    33.550000
# mod_RPE_PRcone_Lukowski_singlePR                                           33.550000
# mod_RPE_PRcone_Lukowski_singleRPE                                          33.550000
# mod_RPE_PRcontrol                                                          33.550000
# mod_RPE_PRrod_Liang                                                        33.550000
# mod_RPE_PRrod_Liang_singlePR                                               33.550000
# mod_RPE_PRrod_Liang_singleRPE                                              33.550000
# mod_RPE_PRrod_Lukowski                                                     33.550000
# mod_RPE_PRrod_Lukowski_singlePR                                            33.550000
# mod_RPE_PRrod_Lukowski_singleRPE                                           33.550000
# Human1_old                                                                 33.550000
# RPE_PR_old                                                                 33.817259
#
#                                    9 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                         35.550000
# mod_RPE_PRcone_Liang                                                       35.550000
# mod_RPE_PRcone_Liang_singlePR                                              35.550000
# mod_RPE_PRcone_Liang_singleRPE                                             35.550000
# mod_RPE_PRcone_Lukowski                                                    35.550000
# mod_RPE_PRcone_Lukowski_singlePR                                           35.550000
# mod_RPE_PRcone_Lukowski_singleRPE                                          35.550000
# mod_RPE_PRcontrol                                                          35.550000
# mod_RPE_PRrod_Liang                                                        35.550000
# mod_RPE_PRrod_Liang_singlePR                                               35.550000
# mod_RPE_PRrod_Liang_singleRPE                                              35.550000
# mod_RPE_PRrod_Lukowski                                                     35.550000
# mod_RPE_PRrod_Lukowski_singlePR                                            35.550000
# mod_RPE_PRrod_Lukowski_singleRPE                                           35.550000
# Human1_old                                                                 35.550000
# RPE_PR_old                                                                 35.817259
#
#                                    10 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                         37.550000
# mod_RPE_PRcone_Liang                                                       37.550000
# mod_RPE_PRcone_Liang_singlePR                                              37.550000
# mod_RPE_PRcone_Liang_singleRPE                                             37.550000
# mod_RPE_PRcone_Lukowski                                                    37.550000
# mod_RPE_PRcone_Lukowski_singlePR                                           37.550000
# mod_RPE_PRcone_Lukowski_singleRPE                                          37.550000
# mod_RPE_PRcontrol                                                          37.550000
# mod_RPE_PRrod_Liang                                                        37.550000
# mod_RPE_PRrod_Liang_singlePR                                               37.550000
# mod_RPE_PRrod_Liang_singleRPE                                              37.550000
# mod_RPE_PRrod_Lukowski                                                     37.550000
# mod_RPE_PRrod_Lukowski_singlePR                                            37.550000
# mod_RPE_PRrod_Lukowski_singleRPE                                           37.550000
# Human1_old                                                                 37.550000
# RPE_PR_old                                                                 37.817259
#
#                                    100 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                        217.550000
# mod_RPE_PRcone_Liang                                                      217.550000
# mod_RPE_PRcone_Liang_singlePR                                             217.550000
# mod_RPE_PRcone_Liang_singleRPE                                            217.550000
# mod_RPE_PRcone_Lukowski                                                   217.550000
# mod_RPE_PRcone_Lukowski_singlePR                                          217.550000
# mod_RPE_PRcone_Lukowski_singleRPE                                         217.550000
# mod_RPE_PRcontrol                                                         217.550000
# mod_RPE_PRrod_Liang                                                       217.550000
# mod_RPE_PRrod_Liang_singlePR                                              217.550000
# mod_RPE_PRrod_Liang_singleRPE                                             217.550000
# mod_RPE_PRrod_Lukowski                                                    217.550000
# mod_RPE_PRrod_Lukowski_singlePR                                           217.550000
# mod_RPE_PRrod_Lukowski_singleRPE                                          217.550000
# Human1_old                                                                217.550000
# RPE_PR_old                                                                217.817259
#
#                                    1000 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)
# Human-GEM_28062023                                                            1000.0
# mod_RPE_PRcone_Liang                                                          1000.0
# mod_RPE_PRcone_Liang_singlePR                                                 1000.0
# mod_RPE_PRcone_Liang_singleRPE                                                1000.0
# mod_RPE_PRcone_Lukowski                                                       1000.0
# mod_RPE_PRcone_Lukowski_singlePR                                              1000.0
# mod_RPE_PRcone_Lukowski_singleRPE                                             1000.0
# mod_RPE_PRcontrol                                                             1000.0
# mod_RPE_PRrod_Liang                                                           1000.0
# mod_RPE_PRrod_Liang_singlePR                                                  1000.0
# mod_RPE_PRrod_Liang_singleRPE                                                 1000.0
# mod_RPE_PRrod_Lukowski                                                        1000.0
# mod_RPE_PRrod_Lukowski_singlePR                                               1000.0
# mod_RPE_PRrod_Lukowski_singleRPE                                              1000.0
# Human1_old                                                                    1000.0
# RPE_PR_old                                                                    1000.0

# %%
sweep_list = [1,2,3,4,4.18,5,6,7,8,9, 10, 100, 1000]
sweep_reaction = 'MAR09034'
ex_bounds = {'MAR09048':(0,1000),'MAR09034':(-4.18,1000),'MAR09135':(0,1000)}
df5 = fba_(model_list, ex_bounds, sweep_list, sweep_reaction)
df5
# Out:
#                                    1 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                               2.0
# mod_RPE_PRcone_Liang                                                             2.0
# mod_RPE_PRcone_Liang_singlePR                                                    2.0
# mod_RPE_PRcone_Liang_singleRPE                                                   2.0
# mod_RPE_PRcone_Lukowski                                                          2.0
# mod_RPE_PRcone_Lukowski_singlePR                                                 2.0
# mod_RPE_PRcone_Lukowski_singleRPE                                                2.0
# mod_RPE_PRcontrol                                                                2.0
# mod_RPE_PRrod_Liang                                                              2.0
# mod_RPE_PRrod_Liang_singlePR                                                     2.0
# mod_RPE_PRrod_Liang_singleRPE                                                    2.0
# mod_RPE_PRrod_Lukowski                                                           2.0
# mod_RPE_PRrod_Lukowski_singlePR                                                  2.0
# mod_RPE_PRrod_Lukowski_singleRPE                                                 2.0
# Human1_old                                                                       2.0
# RPE_PR_old                                                                       2.0
#
#                                    2 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                               4.0
# mod_RPE_PRcone_Liang                                                             4.0
# mod_RPE_PRcone_Liang_singlePR                                                    4.0
# mod_RPE_PRcone_Liang_singleRPE                                                   4.0
# mod_RPE_PRcone_Lukowski                                                          4.0
# mod_RPE_PRcone_Lukowski_singlePR                                                 4.0
# mod_RPE_PRcone_Lukowski_singleRPE                                                4.0
# mod_RPE_PRcontrol                                                                4.0
# mod_RPE_PRrod_Liang                                                              4.0
# mod_RPE_PRrod_Liang_singlePR                                                     4.0
# mod_RPE_PRrod_Liang_singleRPE                                                    4.0
# mod_RPE_PRrod_Lukowski                                                           4.0
# mod_RPE_PRrod_Lukowski_singlePR                                                  4.0
# mod_RPE_PRrod_Lukowski_singleRPE                                                 4.0
# Human1_old                                                                       4.0
# RPE_PR_old                                                                       4.0
#
#                                    3 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                               6.0
# mod_RPE_PRcone_Liang                                                             6.0
# mod_RPE_PRcone_Liang_singlePR                                                    6.0
# mod_RPE_PRcone_Liang_singleRPE                                                   6.0
# mod_RPE_PRcone_Lukowski                                                          6.0
# mod_RPE_PRcone_Lukowski_singlePR                                                 6.0
# mod_RPE_PRcone_Lukowski_singleRPE                                                6.0
# mod_RPE_PRcontrol                                                                6.0
# mod_RPE_PRrod_Liang                                                              6.0
# mod_RPE_PRrod_Liang_singlePR                                                     6.0
# mod_RPE_PRrod_Liang_singleRPE                                                    6.0
# mod_RPE_PRrod_Lukowski                                                           6.0
# mod_RPE_PRrod_Lukowski_singlePR                                                  6.0
# mod_RPE_PRrod_Lukowski_singleRPE                                                 6.0
# Human1_old                                                                       6.0
# RPE_PR_old                                                                       6.0
#
#                                    4 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                               8.0
# mod_RPE_PRcone_Liang                                                             8.0
# mod_RPE_PRcone_Liang_singlePR                                                    8.0
# mod_RPE_PRcone_Liang_singleRPE                                                   8.0
# mod_RPE_PRcone_Lukowski                                                          8.0
# mod_RPE_PRcone_Lukowski_singlePR                                                 8.0
# mod_RPE_PRcone_Lukowski_singleRPE                                                8.0
# mod_RPE_PRcontrol                                                                8.0
# mod_RPE_PRrod_Liang                                                              8.0
# mod_RPE_PRrod_Liang_singlePR                                                     8.0
# mod_RPE_PRrod_Liang_singleRPE                                                    8.0
# mod_RPE_PRrod_Lukowski                                                           8.0
# mod_RPE_PRrod_Lukowski_singlePR                                                  8.0
# mod_RPE_PRrod_Lukowski_singleRPE                                                 8.0
# Human1_old                                                                       8.0
# RPE_PR_old                                                                       8.0
#
#                                    4.18 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                              8.36
# mod_RPE_PRcone_Liang                                                            8.36
# mod_RPE_PRcone_Liang_singlePR                                                   8.36
# mod_RPE_PRcone_Liang_singleRPE                                                  8.36
# mod_RPE_PRcone_Lukowski                                                         8.36
# mod_RPE_PRcone_Lukowski_singlePR                                                8.36
# mod_RPE_PRcone_Lukowski_singleRPE                                               8.36
# mod_RPE_PRcontrol                                                               8.36
# mod_RPE_PRrod_Liang                                                             8.36
# mod_RPE_PRrod_Liang_singlePR                                                    8.36
# mod_RPE_PRrod_Liang_singleRPE                                                   8.36
# mod_RPE_PRrod_Lukowski                                                          8.36
# mod_RPE_PRrod_Lukowski_singlePR                                                 8.36
# mod_RPE_PRrod_Lukowski_singleRPE                                                8.36
# Human1_old                                                                      8.36
# RPE_PR_old                                                                      8.36
#
#                                    5 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                              10.0
# mod_RPE_PRcone_Liang                                                            10.0
# mod_RPE_PRcone_Liang_singlePR                                                   10.0
# mod_RPE_PRcone_Liang_singleRPE                                                  10.0
# mod_RPE_PRcone_Lukowski                                                         10.0
# mod_RPE_PRcone_Lukowski_singlePR                                                10.0
# mod_RPE_PRcone_Lukowski_singleRPE                                               10.0
# mod_RPE_PRcontrol                                                               10.0
# mod_RPE_PRrod_Liang                                                             10.0
# mod_RPE_PRrod_Liang_singlePR                                                    10.0
# mod_RPE_PRrod_Liang_singleRPE                                                   10.0
# mod_RPE_PRrod_Lukowski                                                          10.0
# mod_RPE_PRrod_Lukowski_singlePR                                                 10.0
# mod_RPE_PRrod_Lukowski_singleRPE                                                10.0
# Human1_old                                                                      10.0
# RPE_PR_old                                                                      10.0
#
#                                    6 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                              12.0
# mod_RPE_PRcone_Liang                                                            12.0
# mod_RPE_PRcone_Liang_singlePR                                                   12.0
# mod_RPE_PRcone_Liang_singleRPE                                                  12.0
# mod_RPE_PRcone_Lukowski                                                         12.0
# mod_RPE_PRcone_Lukowski_singlePR                                                12.0
# mod_RPE_PRcone_Lukowski_singleRPE                                               12.0
# mod_RPE_PRcontrol                                                               12.0
# mod_RPE_PRrod_Liang                                                             12.0
# mod_RPE_PRrod_Liang_singlePR                                                    12.0
# mod_RPE_PRrod_Liang_singleRPE                                                   12.0
# mod_RPE_PRrod_Lukowski                                                          12.0
# mod_RPE_PRrod_Lukowski_singlePR                                                 12.0
# mod_RPE_PRrod_Lukowski_singleRPE                                                12.0
# Human1_old                                                                      12.0
# RPE_PR_old                                                                      12.0
#
#                                    7 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                              14.0
# mod_RPE_PRcone_Liang                                                            14.0
# mod_RPE_PRcone_Liang_singlePR                                                   14.0
# mod_RPE_PRcone_Liang_singleRPE                                                  14.0
# mod_RPE_PRcone_Lukowski                                                         14.0
# mod_RPE_PRcone_Lukowski_singlePR                                                14.0
# mod_RPE_PRcone_Lukowski_singleRPE                                               14.0
# mod_RPE_PRcontrol                                                               14.0
# mod_RPE_PRrod_Liang                                                             14.0
# mod_RPE_PRrod_Liang_singlePR                                                    14.0
# mod_RPE_PRrod_Liang_singleRPE                                                   14.0
# mod_RPE_PRrod_Lukowski                                                          14.0
# mod_RPE_PRrod_Lukowski_singlePR                                                 14.0
# mod_RPE_PRrod_Lukowski_singleRPE                                                14.0
# Human1_old                                                                      14.0
# RPE_PR_old                                                                      14.0
#
#                                    8 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                              16.0
# mod_RPE_PRcone_Liang                                                            16.0
# mod_RPE_PRcone_Liang_singlePR                                                   16.0
# mod_RPE_PRcone_Liang_singleRPE                                                  16.0
# mod_RPE_PRcone_Lukowski                                                         16.0
# mod_RPE_PRcone_Lukowski_singlePR                                                16.0
# mod_RPE_PRcone_Lukowski_singleRPE                                               16.0
# mod_RPE_PRcontrol                                                               16.0
# mod_RPE_PRrod_Liang                                                             16.0
# mod_RPE_PRrod_Liang_singlePR                                                    16.0
# mod_RPE_PRrod_Liang_singleRPE                                                   16.0
# mod_RPE_PRrod_Lukowski                                                          16.0
# mod_RPE_PRrod_Lukowski_singlePR                                                 16.0
# mod_RPE_PRrod_Lukowski_singleRPE                                                16.0
# Human1_old                                                                      16.0
# RPE_PR_old                                                                      16.0
#
#                                    9 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                              18.0
# mod_RPE_PRcone_Liang                                                            18.0
# mod_RPE_PRcone_Liang_singlePR                                                   18.0
# mod_RPE_PRcone_Liang_singleRPE                                                  18.0
# mod_RPE_PRcone_Lukowski                                                         18.0
# mod_RPE_PRcone_Lukowski_singlePR                                                18.0
# mod_RPE_PRcone_Lukowski_singleRPE                                               18.0
# mod_RPE_PRcontrol                                                               18.0
# mod_RPE_PRrod_Liang                                                             18.0
# mod_RPE_PRrod_Liang_singlePR                                                    18.0
# mod_RPE_PRrod_Liang_singleRPE                                                   18.0
# mod_RPE_PRrod_Lukowski                                                          18.0
# mod_RPE_PRrod_Lukowski_singlePR                                                 18.0
# mod_RPE_PRrod_Lukowski_singleRPE                                                18.0
# Human1_old                                                                      18.0
# RPE_PR_old                                                                      18.0
#
#                                    10 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                              20.0
# mod_RPE_PRcone_Liang                                                            20.0
# mod_RPE_PRcone_Liang_singlePR                                                   20.0
# mod_RPE_PRcone_Liang_singleRPE                                                  20.0
# mod_RPE_PRcone_Lukowski                                                         20.0
# mod_RPE_PRcone_Lukowski_singlePR                                                20.0
# mod_RPE_PRcone_Lukowski_singleRPE                                               20.0
# mod_RPE_PRcontrol                                                               20.0
# mod_RPE_PRrod_Liang                                                             20.0
# mod_RPE_PRrod_Liang_singlePR                                                    20.0
# mod_RPE_PRrod_Liang_singleRPE                                                   20.0
# mod_RPE_PRrod_Lukowski                                                          20.0
# mod_RPE_PRrod_Lukowski_singlePR                                                 20.0
# mod_RPE_PRrod_Lukowski_singleRPE                                                20.0
# Human1_old                                                                      20.0
# RPE_PR_old                                                                      20.0
#
#                                    100 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                             200.0
# mod_RPE_PRcone_Liang                                                           200.0
# mod_RPE_PRcone_Liang_singlePR                                                  200.0
# mod_RPE_PRcone_Liang_singleRPE                                                 200.0
# mod_RPE_PRcone_Lukowski                                                        200.0
# mod_RPE_PRcone_Lukowski_singlePR                                               200.0
# mod_RPE_PRcone_Lukowski_singleRPE                                              200.0
# mod_RPE_PRcontrol                                                              200.0
# mod_RPE_PRrod_Liang                                                            200.0
# mod_RPE_PRrod_Liang_singlePR                                                   200.0
# mod_RPE_PRrod_Liang_singleRPE                                                  200.0
# mod_RPE_PRrod_Lukowski                                                         200.0
# mod_RPE_PRrod_Lukowski_singlePR                                                200.0
# mod_RPE_PRrod_Lukowski_singleRPE                                               200.0
# Human1_old                                                                     200.0
# RPE_PR_old                                                                     200.0
#
#                                    1000 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)
# Human-GEM_28062023                                                            1000.0
# mod_RPE_PRcone_Liang                                                          1000.0
# mod_RPE_PRcone_Liang_singlePR                                                 1000.0
# mod_RPE_PRcone_Liang_singleRPE                                                1000.0
# mod_RPE_PRcone_Lukowski                                                       1000.0
# mod_RPE_PRcone_Lukowski_singlePR                                              1000.0
# mod_RPE_PRcone_Lukowski_singleRPE                                             1000.0
# mod_RPE_PRcontrol                                                             1000.0
# mod_RPE_PRrod_Liang                                                           1000.0
# mod_RPE_PRrod_Liang_singlePR                                                  1000.0
# mod_RPE_PRrod_Liang_singleRPE                                                 1000.0
# mod_RPE_PRrod_Lukowski                                                        1000.0
# mod_RPE_PRrod_Lukowski_singlePR                                               1000.0
# mod_RPE_PRrod_Lukowski_singleRPE                                              1000.0
# Human1_old                                                                    1000.0
# RPE_PR_old                                                                    1000.0

# %%
sweep_list = [1,2,3,4,4.18,5,6,7,8,9, 10, 100, 1000]
sweep_reaction = 'MAR09034'
ex_bounds = {'MAR09048':(-1000,1000),'MAR09034':(-4.18,1000),'MAR09135':(0,1000)}
df6 = fba_(model_list, ex_bounds, sweep_list, sweep_reaction)
df6
# Out:
#                                    1 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                             31.50
# mod_RPE_PRcone_Liang                                                           29.75
# mod_RPE_PRcone_Liang_singlePR                                                   7.00
# mod_RPE_PRcone_Liang_singleRPE                                                 29.00
# mod_RPE_PRcone_Lukowski                                                        31.50
# mod_RPE_PRcone_Lukowski_singlePR                                               26.00
# mod_RPE_PRcone_Lukowski_singleRPE                                              29.00
# mod_RPE_PRcontrol                                                              31.50
# mod_RPE_PRrod_Liang                                                            29.75
# mod_RPE_PRrod_Liang_singlePR                                                   12.00
# mod_RPE_PRrod_Liang_singleRPE                                                  29.00
# mod_RPE_PRrod_Lukowski                                                         31.50
# mod_RPE_PRrod_Lukowski_singlePR                                                29.00
# mod_RPE_PRrod_Lukowski_singleRPE                                               29.00
# Human1_old                                                                     31.50
# RPE_PR_old                                                                     31.50
#
#                                    2 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                              63.0
# mod_RPE_PRcone_Liang                                                            59.5
# mod_RPE_PRcone_Liang_singlePR                                                   14.0
# mod_RPE_PRcone_Liang_singleRPE                                                  58.0
# mod_RPE_PRcone_Lukowski                                                         63.0
# mod_RPE_PRcone_Lukowski_singlePR                                                52.0
# mod_RPE_PRcone_Lukowski_singleRPE                                               58.0
# mod_RPE_PRcontrol                                                               63.0
# mod_RPE_PRrod_Liang                                                             59.5
# mod_RPE_PRrod_Liang_singlePR                                                    24.0
# mod_RPE_PRrod_Liang_singleRPE                                                   58.0
# mod_RPE_PRrod_Lukowski                                                          63.0
# mod_RPE_PRrod_Lukowski_singlePR                                                 58.0
# mod_RPE_PRrod_Lukowski_singleRPE                                                58.0
# Human1_old                                                                      63.0
# RPE_PR_old                                                                      63.0
#
#                                    3 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                             94.50
# mod_RPE_PRcone_Liang                                                           89.25
# mod_RPE_PRcone_Liang_singlePR                                                  21.00
# mod_RPE_PRcone_Liang_singleRPE                                                 87.00
# mod_RPE_PRcone_Lukowski                                                        94.50
# mod_RPE_PRcone_Lukowski_singlePR                                               78.00
# mod_RPE_PRcone_Lukowski_singleRPE                                              87.00
# mod_RPE_PRcontrol                                                              94.50
# mod_RPE_PRrod_Liang                                                            89.25
# mod_RPE_PRrod_Liang_singlePR                                                   36.00
# mod_RPE_PRrod_Liang_singleRPE                                                  87.00
# mod_RPE_PRrod_Lukowski                                                         94.50
# mod_RPE_PRrod_Lukowski_singlePR                                                87.00
# mod_RPE_PRrod_Lukowski_singleRPE                                               87.00
# Human1_old                                                                     94.50
# RPE_PR_old                                                                     94.50
#
#                                    4 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                             126.0
# mod_RPE_PRcone_Liang                                                           119.0
# mod_RPE_PRcone_Liang_singlePR                                                   28.0
# mod_RPE_PRcone_Liang_singleRPE                                                 116.0
# mod_RPE_PRcone_Lukowski                                                        126.0
# mod_RPE_PRcone_Lukowski_singlePR                                               104.0
# mod_RPE_PRcone_Lukowski_singleRPE                                              116.0
# mod_RPE_PRcontrol                                                              126.0
# mod_RPE_PRrod_Liang                                                            119.0
# mod_RPE_PRrod_Liang_singlePR                                                    48.0
# mod_RPE_PRrod_Liang_singleRPE                                                  116.0
# mod_RPE_PRrod_Lukowski                                                         126.0
# mod_RPE_PRrod_Lukowski_singlePR                                                116.0
# mod_RPE_PRrod_Lukowski_singleRPE                                               116.0
# Human1_old                                                                     126.0
# RPE_PR_old                                                                     126.0
#
#                                    4.18 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                           131.670
# mod_RPE_PRcone_Liang                                                         124.355
# mod_RPE_PRcone_Liang_singlePR                                                 29.260
# mod_RPE_PRcone_Liang_singleRPE                                               121.220
# mod_RPE_PRcone_Lukowski                                                      131.670
# mod_RPE_PRcone_Lukowski_singlePR                                             108.680
# mod_RPE_PRcone_Lukowski_singleRPE                                            121.220
# mod_RPE_PRcontrol                                                            131.670
# mod_RPE_PRrod_Liang                                                          124.355
# mod_RPE_PRrod_Liang_singlePR                                                  50.160
# mod_RPE_PRrod_Liang_singleRPE                                                121.220
# mod_RPE_PRrod_Lukowski                                                       131.670
# mod_RPE_PRrod_Lukowski_singlePR                                              121.220
# mod_RPE_PRrod_Lukowski_singleRPE                                             121.220
# Human1_old                                                                   131.670
# RPE_PR_old                                                                   131.670
#
#                                    5 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                            157.50
# mod_RPE_PRcone_Liang                                                          148.75
# mod_RPE_PRcone_Liang_singlePR                                                  35.00
# mod_RPE_PRcone_Liang_singleRPE                                                145.00
# mod_RPE_PRcone_Lukowski                                                       157.50
# mod_RPE_PRcone_Lukowski_singlePR                                              130.00
# mod_RPE_PRcone_Lukowski_singleRPE                                             145.00
# mod_RPE_PRcontrol                                                             157.50
# mod_RPE_PRrod_Liang                                                           148.75
# mod_RPE_PRrod_Liang_singlePR                                                   60.00
# mod_RPE_PRrod_Liang_singleRPE                                                 145.00
# mod_RPE_PRrod_Lukowski                                                        157.50
# mod_RPE_PRrod_Lukowski_singlePR                                               145.00
# mod_RPE_PRrod_Lukowski_singleRPE                                              145.00
# Human1_old                                                                    157.50
# RPE_PR_old                                                                    157.50
#
#                                    6 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                             189.0
# mod_RPE_PRcone_Liang                                                           178.5
# mod_RPE_PRcone_Liang_singlePR                                                   42.0
# mod_RPE_PRcone_Liang_singleRPE                                                 174.0
# mod_RPE_PRcone_Lukowski                                                        189.0
# mod_RPE_PRcone_Lukowski_singlePR                                               156.0
# mod_RPE_PRcone_Lukowski_singleRPE                                              174.0
# mod_RPE_PRcontrol                                                              189.0
# mod_RPE_PRrod_Liang                                                            178.5
# mod_RPE_PRrod_Liang_singlePR                                                    72.0
# mod_RPE_PRrod_Liang_singleRPE                                                  174.0
# mod_RPE_PRrod_Lukowski                                                         189.0
# mod_RPE_PRrod_Lukowski_singlePR                                                174.0
# mod_RPE_PRrod_Lukowski_singleRPE                                               174.0
# Human1_old                                                                     189.0
# RPE_PR_old                                                                     189.0
#
#                                    7 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                            220.50
# mod_RPE_PRcone_Liang                                                          208.25
# mod_RPE_PRcone_Liang_singlePR                                                  49.00
# mod_RPE_PRcone_Liang_singleRPE                                                203.00
# mod_RPE_PRcone_Lukowski                                                       220.50
# mod_RPE_PRcone_Lukowski_singlePR                                              182.00
# mod_RPE_PRcone_Lukowski_singleRPE                                             203.00
# mod_RPE_PRcontrol                                                             220.50
# mod_RPE_PRrod_Liang                                                           208.25
# mod_RPE_PRrod_Liang_singlePR                                                   84.00
# mod_RPE_PRrod_Liang_singleRPE                                                 203.00
# mod_RPE_PRrod_Lukowski                                                        220.50
# mod_RPE_PRrod_Lukowski_singlePR                                               203.00
# mod_RPE_PRrod_Lukowski_singleRPE                                              203.00
# Human1_old                                                                    220.50
# RPE_PR_old                                                                    220.50
#
#                                    8 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                             252.0
# mod_RPE_PRcone_Liang                                                           238.0
# mod_RPE_PRcone_Liang_singlePR                                                   56.0
# mod_RPE_PRcone_Liang_singleRPE                                                 232.0
# mod_RPE_PRcone_Lukowski                                                        252.0
# mod_RPE_PRcone_Lukowski_singlePR                                               208.0
# mod_RPE_PRcone_Lukowski_singleRPE                                              232.0
# mod_RPE_PRcontrol                                                              252.0
# mod_RPE_PRrod_Liang                                                            238.0
# mod_RPE_PRrod_Liang_singlePR                                                    96.0
# mod_RPE_PRrod_Liang_singleRPE                                                  232.0
# mod_RPE_PRrod_Lukowski                                                         252.0
# mod_RPE_PRrod_Lukowski_singlePR                                                232.0
# mod_RPE_PRrod_Lukowski_singleRPE                                               232.0
# Human1_old                                                                     252.0
# RPE_PR_old                                                                     252.0
#
#                                    9 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                            283.50
# mod_RPE_PRcone_Liang                                                          267.75
# mod_RPE_PRcone_Liang_singlePR                                                  63.00
# mod_RPE_PRcone_Liang_singleRPE                                                261.00
# mod_RPE_PRcone_Lukowski                                                       283.50
# mod_RPE_PRcone_Lukowski_singlePR                                              234.00
# mod_RPE_PRcone_Lukowski_singleRPE                                             261.00
# mod_RPE_PRcontrol                                                             283.50
# mod_RPE_PRrod_Liang                                                           267.75
# mod_RPE_PRrod_Liang_singlePR                                                  108.00
# mod_RPE_PRrod_Liang_singleRPE                                                 261.00
# mod_RPE_PRrod_Lukowski                                                        283.50
# mod_RPE_PRrod_Lukowski_singlePR                                               261.00
# mod_RPE_PRrod_Lukowski_singleRPE                                              261.00
# Human1_old                                                                    283.50
# RPE_PR_old                                                                    283.50
#
#                                    10 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                             315.0
# mod_RPE_PRcone_Liang                                                           297.5
# mod_RPE_PRcone_Liang_singlePR                                                   70.0
# mod_RPE_PRcone_Liang_singleRPE                                                 290.0
# mod_RPE_PRcone_Lukowski                                                        315.0
# mod_RPE_PRcone_Lukowski_singlePR                                               260.0
# mod_RPE_PRcone_Lukowski_singleRPE                                              290.0
# mod_RPE_PRcontrol                                                              315.0
# mod_RPE_PRrod_Liang                                                            297.5
# mod_RPE_PRrod_Liang_singlePR                                                   120.0
# mod_RPE_PRrod_Liang_singleRPE                                                  290.0
# mod_RPE_PRrod_Lukowski                                                         315.0
# mod_RPE_PRrod_Lukowski_singlePR                                                290.0
# mod_RPE_PRrod_Lukowski_singleRPE                                               290.0
# Human1_old                                                                     315.0
# RPE_PR_old                                                                     315.0
#
#                                    100 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                            1000.0
# mod_RPE_PRcone_Liang                                                          1000.0
# mod_RPE_PRcone_Liang_singlePR                                                  700.0
# mod_RPE_PRcone_Liang_singleRPE                                                1000.0
# mod_RPE_PRcone_Lukowski                                                       1000.0
# mod_RPE_PRcone_Lukowski_singlePR                                              1000.0
# mod_RPE_PRcone_Lukowski_singleRPE                                             1000.0
# mod_RPE_PRcontrol                                                             1000.0
# mod_RPE_PRrod_Liang                                                           1000.0
# mod_RPE_PRrod_Liang_singlePR                                                  1000.0
# mod_RPE_PRrod_Liang_singleRPE                                                 1000.0
# mod_RPE_PRrod_Lukowski                                                        1000.0
# mod_RPE_PRrod_Lukowski_singlePR                                               1000.0
# mod_RPE_PRrod_Lukowski_singleRPE                                              1000.0
# Human1_old                                                                    1000.0
# RPE_PR_old                                                                    1000.0
#
#                                    1000 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)
# Human-GEM_28062023                                                            1000.0
# mod_RPE_PRcone_Liang                                                          1000.0
# mod_RPE_PRcone_Liang_singlePR                                                 1000.0
# mod_RPE_PRcone_Liang_singleRPE                                                1000.0
# mod_RPE_PRcone_Lukowski                                                       1000.0
# mod_RPE_PRcone_Lukowski_singlePR                                              1000.0
# mod_RPE_PRcone_Lukowski_singleRPE                                             1000.0
# mod_RPE_PRcontrol                                                             1000.0
# mod_RPE_PRrod_Liang                                                           1000.0
# mod_RPE_PRrod_Liang_singlePR                                                  1000.0
# mod_RPE_PRrod_Liang_singleRPE                                                 1000.0
# mod_RPE_PRrod_Lukowski                                                        1000.0
# mod_RPE_PRrod_Lukowski_singlePR                                               1000.0
# mod_RPE_PRrod_Lukowski_singleRPE                                              1000.0
# Human1_old                                                                    1000.0
# RPE_PR_old                                                                    1000.0

# %%
sweep_list = [1,2,3,4,4.18,5,6,7,8,9, 10, 100, 1000]
sweep_reaction = 'MAR09034'
ex_bounds = {'MAR09048':(-1000,1000),'MAR09034':(-4.18,1000),'MAR09135':(-1000,1000)}
df7 = fba_(model_list, ex_bounds, sweep_list, sweep_reaction)
df7
# Out:
#                                    1 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                            1000.0
# mod_RPE_PRcone_Liang                                                          1000.0
# mod_RPE_PRcone_Liang_singlePR                                                 1000.0
# mod_RPE_PRcone_Liang_singleRPE                                                1000.0
# mod_RPE_PRcone_Lukowski                                                       1000.0
# mod_RPE_PRcone_Lukowski_singlePR                                              1000.0
# mod_RPE_PRcone_Lukowski_singleRPE                                             1000.0
# mod_RPE_PRcontrol                                                             1000.0
# mod_RPE_PRrod_Liang                                                           1000.0
# mod_RPE_PRrod_Liang_singlePR                                                  1000.0
# mod_RPE_PRrod_Liang_singleRPE                                                 1000.0
# mod_RPE_PRrod_Lukowski                                                        1000.0
# mod_RPE_PRrod_Lukowski_singlePR                                               1000.0
# mod_RPE_PRrod_Lukowski_singleRPE                                              1000.0
# Human1_old                                                                    1000.0
# RPE_PR_old                                                                    1000.0
#
#                                    2 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                            1000.0
# mod_RPE_PRcone_Liang                                                          1000.0
# mod_RPE_PRcone_Liang_singlePR                                                 1000.0
# mod_RPE_PRcone_Liang_singleRPE                                                1000.0
# mod_RPE_PRcone_Lukowski                                                       1000.0
# mod_RPE_PRcone_Lukowski_singlePR                                              1000.0
# mod_RPE_PRcone_Lukowski_singleRPE                                             1000.0
# mod_RPE_PRcontrol                                                             1000.0
# mod_RPE_PRrod_Liang                                                           1000.0
# mod_RPE_PRrod_Liang_singlePR                                                  1000.0
# mod_RPE_PRrod_Liang_singleRPE                                                 1000.0
# mod_RPE_PRrod_Lukowski                                                        1000.0
# mod_RPE_PRrod_Lukowski_singlePR                                               1000.0
# mod_RPE_PRrod_Lukowski_singleRPE                                              1000.0
# Human1_old                                                                    1000.0
# RPE_PR_old                                                                    1000.0
#
#                                    3 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                            1000.0
# mod_RPE_PRcone_Liang                                                          1000.0
# mod_RPE_PRcone_Liang_singlePR                                                 1000.0
# mod_RPE_PRcone_Liang_singleRPE                                                1000.0
# mod_RPE_PRcone_Lukowski                                                       1000.0
# mod_RPE_PRcone_Lukowski_singlePR                                              1000.0
# mod_RPE_PRcone_Lukowski_singleRPE                                             1000.0
# mod_RPE_PRcontrol                                                             1000.0
# mod_RPE_PRrod_Liang                                                           1000.0
# mod_RPE_PRrod_Liang_singlePR                                                  1000.0
# mod_RPE_PRrod_Liang_singleRPE                                                 1000.0
# mod_RPE_PRrod_Lukowski                                                        1000.0
# mod_RPE_PRrod_Lukowski_singlePR                                               1000.0
# mod_RPE_PRrod_Lukowski_singleRPE                                              1000.0
# Human1_old                                                                    1000.0
# RPE_PR_old                                                                    1000.0
#
#                                    4 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                            1000.0
# mod_RPE_PRcone_Liang                                                          1000.0
# mod_RPE_PRcone_Liang_singlePR                                                 1000.0
# mod_RPE_PRcone_Liang_singleRPE                                                1000.0
# mod_RPE_PRcone_Lukowski                                                       1000.0
# mod_RPE_PRcone_Lukowski_singlePR                                              1000.0
# mod_RPE_PRcone_Lukowski_singleRPE                                             1000.0
# mod_RPE_PRcontrol                                                             1000.0
# mod_RPE_PRrod_Liang                                                           1000.0
# mod_RPE_PRrod_Liang_singlePR                                                  1000.0
# mod_RPE_PRrod_Liang_singleRPE                                                 1000.0
# mod_RPE_PRrod_Lukowski                                                        1000.0
# mod_RPE_PRrod_Lukowski_singlePR                                               1000.0
# mod_RPE_PRrod_Lukowski_singleRPE                                              1000.0
# Human1_old                                                                    1000.0
# RPE_PR_old                                                                    1000.0
#
#                                    4.18 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                            1000.0
# mod_RPE_PRcone_Liang                                                          1000.0
# mod_RPE_PRcone_Liang_singlePR                                                 1000.0
# mod_RPE_PRcone_Liang_singleRPE                                                1000.0
# mod_RPE_PRcone_Lukowski                                                       1000.0
# mod_RPE_PRcone_Lukowski_singlePR                                              1000.0
# mod_RPE_PRcone_Lukowski_singleRPE                                             1000.0
# mod_RPE_PRcontrol                                                             1000.0
# mod_RPE_PRrod_Liang                                                           1000.0
# mod_RPE_PRrod_Liang_singlePR                                                  1000.0
# mod_RPE_PRrod_Liang_singleRPE                                                 1000.0
# mod_RPE_PRrod_Lukowski                                                        1000.0
# mod_RPE_PRrod_Lukowski_singlePR                                               1000.0
# mod_RPE_PRrod_Lukowski_singleRPE                                              1000.0
# Human1_old                                                                    1000.0
# RPE_PR_old                                                                    1000.0
#
#                                    5 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                            1000.0
# mod_RPE_PRcone_Liang                                                          1000.0
# mod_RPE_PRcone_Liang_singlePR                                                 1000.0
# mod_RPE_PRcone_Liang_singleRPE                                                1000.0
# mod_RPE_PRcone_Lukowski                                                       1000.0
# mod_RPE_PRcone_Lukowski_singlePR                                              1000.0
# mod_RPE_PRcone_Lukowski_singleRPE                                             1000.0
# mod_RPE_PRcontrol                                                             1000.0
# mod_RPE_PRrod_Liang                                                           1000.0
# mod_RPE_PRrod_Liang_singlePR                                                  1000.0
# mod_RPE_PRrod_Liang_singleRPE                                                 1000.0
# mod_RPE_PRrod_Lukowski                                                        1000.0
# mod_RPE_PRrod_Lukowski_singlePR                                               1000.0
# mod_RPE_PRrod_Lukowski_singleRPE                                              1000.0
# Human1_old                                                                    1000.0
# RPE_PR_old                                                                    1000.0
#
#                                    6 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                            1000.0
# mod_RPE_PRcone_Liang                                                          1000.0
# mod_RPE_PRcone_Liang_singlePR                                                 1000.0
# mod_RPE_PRcone_Liang_singleRPE                                                1000.0
# mod_RPE_PRcone_Lukowski                                                       1000.0
# mod_RPE_PRcone_Lukowski_singlePR                                              1000.0
# mod_RPE_PRcone_Lukowski_singleRPE                                             1000.0
# mod_RPE_PRcontrol                                                             1000.0
# mod_RPE_PRrod_Liang                                                           1000.0
# mod_RPE_PRrod_Liang_singlePR                                                  1000.0
# mod_RPE_PRrod_Liang_singleRPE                                                 1000.0
# mod_RPE_PRrod_Lukowski                                                        1000.0
# mod_RPE_PRrod_Lukowski_singlePR                                               1000.0
# mod_RPE_PRrod_Lukowski_singleRPE                                              1000.0
# Human1_old                                                                    1000.0
# RPE_PR_old                                                                    1000.0
#
#                                    7 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                            1000.0
# mod_RPE_PRcone_Liang                                                          1000.0
# mod_RPE_PRcone_Liang_singlePR                                                 1000.0
# mod_RPE_PRcone_Liang_singleRPE                                                1000.0
# mod_RPE_PRcone_Lukowski                                                       1000.0
# mod_RPE_PRcone_Lukowski_singlePR                                              1000.0
# mod_RPE_PRcone_Lukowski_singleRPE                                             1000.0
# mod_RPE_PRcontrol                                                             1000.0
# mod_RPE_PRrod_Liang                                                           1000.0
# mod_RPE_PRrod_Liang_singlePR                                                  1000.0
# mod_RPE_PRrod_Liang_singleRPE                                                 1000.0
# mod_RPE_PRrod_Lukowski                                                        1000.0
# mod_RPE_PRrod_Lukowski_singlePR                                               1000.0
# mod_RPE_PRrod_Lukowski_singleRPE                                              1000.0
# Human1_old                                                                    1000.0
# RPE_PR_old                                                                    1000.0
#
#                                    8 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                            1000.0
# mod_RPE_PRcone_Liang                                                          1000.0
# mod_RPE_PRcone_Liang_singlePR                                                 1000.0
# mod_RPE_PRcone_Liang_singleRPE                                                1000.0
# mod_RPE_PRcone_Lukowski                                                       1000.0
# mod_RPE_PRcone_Lukowski_singlePR                                              1000.0
# mod_RPE_PRcone_Lukowski_singleRPE                                             1000.0
# mod_RPE_PRcontrol                                                             1000.0
# mod_RPE_PRrod_Liang                                                           1000.0
# mod_RPE_PRrod_Liang_singlePR                                                  1000.0
# mod_RPE_PRrod_Liang_singleRPE                                                 1000.0
# mod_RPE_PRrod_Lukowski                                                        1000.0
# mod_RPE_PRrod_Lukowski_singlePR                                               1000.0
# mod_RPE_PRrod_Lukowski_singleRPE                                              1000.0
# Human1_old                                                                    1000.0
# RPE_PR_old                                                                    1000.0
#
#                                    9 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                            1000.0
# mod_RPE_PRcone_Liang                                                          1000.0
# mod_RPE_PRcone_Liang_singlePR                                                 1000.0
# mod_RPE_PRcone_Liang_singleRPE                                                1000.0
# mod_RPE_PRcone_Lukowski                                                       1000.0
# mod_RPE_PRcone_Lukowski_singlePR                                              1000.0
# mod_RPE_PRcone_Lukowski_singleRPE                                             1000.0
# mod_RPE_PRcontrol                                                             1000.0
# mod_RPE_PRrod_Liang                                                           1000.0
# mod_RPE_PRrod_Liang_singlePR                                                  1000.0
# mod_RPE_PRrod_Liang_singleRPE                                                 1000.0
# mod_RPE_PRrod_Lukowski                                                        1000.0
# mod_RPE_PRrod_Lukowski_singlePR                                               1000.0
# mod_RPE_PRrod_Lukowski_singleRPE                                              1000.0
# Human1_old                                                                    1000.0
# RPE_PR_old                                                                    1000.0
#
#                                    10 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                            1000.0
# mod_RPE_PRcone_Liang                                                          1000.0
# mod_RPE_PRcone_Liang_singlePR                                                 1000.0
# mod_RPE_PRcone_Liang_singleRPE                                                1000.0
# mod_RPE_PRcone_Lukowski                                                       1000.0
# mod_RPE_PRcone_Lukowski_singlePR                                              1000.0
# mod_RPE_PRcone_Lukowski_singleRPE                                             1000.0
# mod_RPE_PRcontrol                                                             1000.0
# mod_RPE_PRrod_Liang                                                           1000.0
# mod_RPE_PRrod_Liang_singlePR                                                  1000.0
# mod_RPE_PRrod_Liang_singleRPE                                                 1000.0
# mod_RPE_PRrod_Lukowski                                                        1000.0
# mod_RPE_PRrod_Lukowski_singlePR                                               1000.0
# mod_RPE_PRrod_Lukowski_singleRPE                                              1000.0
# Human1_old                                                                    1000.0
# RPE_PR_old                                                                    1000.0
#
#                                    100 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)  \
# Human-GEM_28062023                                                            1000.0
# mod_RPE_PRcone_Liang                                                          1000.0
# mod_RPE_PRcone_Liang_singlePR                                                 1000.0
# mod_RPE_PRcone_Liang_singleRPE                                                1000.0
# mod_RPE_PRcone_Lukowski                                                       1000.0
# mod_RPE_PRcone_Lukowski_singlePR                                              1000.0
# mod_RPE_PRcone_Lukowski_singleRPE                                             1000.0
# mod_RPE_PRcontrol                                                             1000.0
# mod_RPE_PRrod_Liang                                                           1000.0
# mod_RPE_PRrod_Liang_singlePR                                                  1000.0
# mod_RPE_PRrod_Liang_singleRPE                                                 1000.0
# mod_RPE_PRrod_Lukowski                                                        1000.0
# mod_RPE_PRrod_Lukowski_singlePR                                               1000.0
# mod_RPE_PRrod_Lukowski_singleRPE                                              1000.0
# Human1_old                                                                    1000.0
# RPE_PR_old                                                                    1000.0
#
#                                    1000 pmol/s/mm^2 influx MAR09034 --- max ATP hydrolysis (pmol/s/mm^2)
# Human-GEM_28062023                                                            1000.0
# mod_RPE_PRcone_Liang                                                          1000.0
# mod_RPE_PRcone_Liang_singlePR                                                 1000.0
# mod_RPE_PRcone_Liang_singleRPE                                                1000.0
# mod_RPE_PRcone_Lukowski                                                       1000.0
# mod_RPE_PRcone_Lukowski_singlePR                                              1000.0
# mod_RPE_PRcone_Lukowski_singleRPE                                             1000.0
# mod_RPE_PRcontrol                                                             1000.0
# mod_RPE_PRrod_Liang                                                           1000.0
# mod_RPE_PRrod_Liang_singlePR                                                  1000.0
# mod_RPE_PRrod_Liang_singleRPE                                                 1000.0
# mod_RPE_PRrod_Lukowski                                                        1000.0
# mod_RPE_PRrod_Lukowski_singlePR                                               1000.0
# mod_RPE_PRrod_Lukowski_singleRPE                                              1000.0
# Human1_old                                                                    1000.0
# RPE_PR_old                                                                    1000.0

# %%
# write dfs to excel
with pd.ExcelWriter('glucose_sweep_max_ATP.xlsx') as writer:
    # spreadsheet 1
    df1.to_excel(writer, sheet_name='max ATP hydrolysis (ox > -3.51, lac > 7.25, glc > -4.18)')
    # spreadsheet 2
    df3.to_excel(writer, sheet_name='ox > -3.51, lac > 7.25')
    # spreadsheet 3
    df4.to_excel(writer, sheet_name='ox > -3.51, lac > 0')
    # spreadsheet 4
    df5.to_excel(writer, sheet_name='ox > 0, lac > 0')
    # spreadsheet 5
    df6.to_excel(writer, sheet_name='ox > -1000, lac > 0')
    # spreadsheet 6
    df7.to_excel(writer, sheet_name='ox > -1000, lac > -1000')
# Out:
# c:\Users\prins\miniconda3\envs\RPE-PR_pytest\lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
